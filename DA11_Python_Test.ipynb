# %%
# import necessary libraries in this cell
# lazımi kitabxanaları bu hücrədə yükləyin

# while working you can add new libraries here
# tapşırıqları həll etdikcə çatışmayan kitabxanaları bu hissəyə əlavə edib yenidən icra edə bilərsiniz.

# %%
# max row and columns to display
pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", 500)

# width of DataFrame
pd.set_option("display.width", 1000)

# Float number formatting
pd.options.display.float_format = "{:,.2f}".format

# p-value decimal formatting
# np.set_printoptions(suppress=True)

# %% [markdown]
# #### 1. String Operations

# %%
# Clean the below-mentioned string
# Aşağıdakı string-i təmizləyin

# remove extra spaces
# only first letter is capital, the other letters are lowercase.
# remove extra dots and asteriks (star)

# lazımsız boşluqları silin
# ancaq ilk hərf böyük, qalanları kiçik olsun
# lazımsız nöqtə və ulduz işarələrini silin
# cümlə nöqtə ilə bitsin.
text1 = "  iT is    a mEsSy  text****   with   A lOT of errors....  "
# Out:
# 'It is a messy text with a lot of errors.'

# %%
# result should be like below
# nəticə aşağıdakı kimi olmalıdır

'It is a messy text with a lot of errors.'

# %% [markdown]
# #### 2. List, Dictionary, DataFrame

# %%
# a) Create a dict from given lists (with zip or for loop, both are acceptable)
# a) Aşağıda verilən list-dən dictionary yaradın.

students = ['Jane', 'Mark', "Deborah", 'Mathew', 'Clementine', "Catherine"]
marks = [52, 90, 84, 75, 63, 95]

# b) print seperately keys and values
# b) key və value-ları ayrılıqda çap edin

# c) Create a DataFrame from this dictionary 
# c) bu dictionary-dən DataFrame yaradın

# %% [markdown]
# #### 3. Numpy array operations

# %%
# a) create a 2x3 matrix that contain only zeros
# a) sadəcə 0-dan ibarət 2x3 ölçülü matris yaradın

# b) create a 5x5 matrix that contain only ones
# b) sadəcə 1-dən ibarət 5x5 ölçülü matris yaradın

arr1 = np.ndarray([1, 5, 4, 3, 2, 10, 6, 7])
# c) multiply each element of the array 'arr1' by 3 (assign to 'arr2')
# c) 'arr1' array-nin hər bir elementini 2-yə vurun və 'arr2' adlı dəyişənə mənimsədin

# d) calculate 2nd degree power for each element of the array 'arr2' (assing to 'arr_sqr')
# d) 'arr2' array-nin hər bir elementini kvadrata yüksəldin və 'arr_sqr' adlı dəyişənə mənimsədin

# e) find mean of 'arr_sqr'
# e) 'arr_sqr' array-nin ədədi ortasını tapın

# %% [markdown]
# #### 4. Read data from .csv

# %%
# read csv data
df = ...(...,
                encoding="latin1")
df

# %%
# print top 5 rows of dataframe

# %%
# print column names of df

# %%
# print 'Actual gross' column

# %%
# Out:
# np.float64(287950903.25)

# %% [markdown]
# #### 5. Data Cleaning

# %%
# clean data for column ' '
# determine what should have change
# for the purpose of this task eliminate all the errorneous and missing rows
# assing new result to variable ' '

# ' ' sütunundakı datanı təmizləyin
# nələri dəyişmək lazım olduğunu özünüz müəyyən edin.
# bu tapşırığın məqsədləri üçün xətalı görünən, düzəldilə bilməyən, və boş sətrləri silin.
# nəticəni " " adlı yeni dəyişənə mənimsədin.

# %% [markdown]
# #### 6. Data CLeaning Function

# %%
# create a function for data cleaning
# add all above task steps inside this function
# this function takes dataframe (as data frame) and column name (as string) as input
# returns new edited column as output (as pd.Series type)

# data cleaning üçün funksiya yaradın (istədiyiniz kimi adlandırın)
# yuxarıdakı tapşırıqda etdiyini prosesi funksiyanın daxilinə əlavə edin
# funksiya parametr olaraq dataframe və sütun adını tələb edir
# output olaraq pd.Series tipində təmizlənmiş sütunu qaytarır

# %%
# use this function to edit our "Actual gross" column
# assign result to new variable 'actual_gross'

# funksiyadan istifadə edərək "Actual gross" sütununu təmizlə
# assign result to new variable 'actual_gross'

# %% [markdown]
# #### 7. Z-test

# %%
# population (hypothetical mean)
pop_mean = ...

# population standard deviation
pop_std = ...

# confidence level and error rate (p-val threshold)
alpha = 0.05

# sample size (here size of our column)
sample_size = ...

# z-score (sample mean - population mean) / square root of sample size
z_score = ...

# a) two tailed test  ---> sample mean == 300_000_000
# p-value (with stats.norm.cdf(z_score)) for each test type
p_value = ...

# decision for each test type (with if else)



# b) right tailed test ---> sample mean > 300_000_000
# p-value (with stats.norm.cdf(z_score)) for each test type
p_value = ...


# decision for each test type (with if else)


# c) left tailed test ---> sample mean < 300_000_000
# p-value (with stats.norm.cdf(z_score)) for each test type
p_value = ...

# decision for each test type (with if else)

# %% [markdown]
# #### 8. Data Viz

# %%
# Create number of each artist name in 'Artist' column
# "Artist" sütunundakı müğənni adlarının təkrarlanma sayını göstərin

# Create a bar chart for 'Artist' column
# "Artist" sütunu üçün bar chart qurun

# %%
# Create a histogram plot for 'Actual Gross' column (cleaned version)
# "Actual Gross" sütunu üçün histogram qurun (təmizlənmiş dəyişəndən istifadə edin)

# %% [markdown]
# #### 9. Create a Class

# %%
# Create a class named "Book"

# attributes: title, author, number_of_pages

# methods:

# --- get_info() ---> prints out title (str), author (str) and number of pages (int)

# --- is_long() ---> if number of pages is more than 200, returns True, else, returns False

# %% [markdown]
# #### 10. Create a Child CLass

# %%
# Create a child class from 'Book' named 'EBook' (electronic book)

# extra attributes: file_size (float)

# extra methods: 
# --- download(as) ---> as takes file format from (pdf, epub, doc) options, prints f"dowloaded as {as}"
# --- get_file_info() ---> return file size and book name (title)

# %% [markdown]
# #### 11. Create a Math Quest

# %%
# define a math question as string like '3 + 5'
# get answer from user with input()
# with assert statement check if the answer is correct, if it is not return an understandable error text.

# %% [markdown]
# #### 12. Create a function with Error Handling

# %%
# create a function that calculates estimated salary

# the base amount is 1000 AZN

# if a person is 'intern', he will get half of base amount
# if a person is 'junior', he will get base amount
# if a person is 'middle', he will get twice of base amount
# if a person is 'senior', he will get triple of base amount


# function has parameter named 'level' and it indicates seniority level


# IMPORTANT NOTE!!! User can put values only in the list ['intern', 'junior', 'middle', 'senior'], 
# if we put something else, it will raise error

# %%
# Təxmini maaşı hesablayan funksiya yaradın.

# Baza məbləği 1000 AZN-dir.

# Əgər şəxs 'intern'-dirsə, baza məbləğinin yarısını alır.
# Əgər şəxs 'junior'-dursa, baza məbləğini alır.
# Əgər şəxs 'middle'-dirsə, baza məbləğinin iki qatını alır.
# Əgər şəxs 'senior'-dursa, baza məbləğinin üç qatını alır.


# Funksiya 'level' adlı parametr qəbul edir. Bu parametr işçinin seniority səviyyəsini göstərir.


# VACİB QEYD:
# İstifadəçi yalnız bu dəyərlərdən birini daxil edə bilər: ['intern', 'junior', 'middle', 'senior']
# Əgər başqa dəyər daxil edilərsə, xəta (error) qaytarılmalıdır.

# %% [markdown]
# #### 13. If Else Statement

# %%
# get age of user with input()

# categorize the user and print result as below-mentioned conditions:

# 0–12 → child
# 13–19 → teen
# 20–64 → adult
# 65+ → senior

# input() funksiyası ilə istifadəçinin yaşını əldə edin

# aşağıdakı şərtlərə görə kateqoriyalaşdırın:

# 0–12 → uşaq
# 13–19 → yeniyetmə
# 20–64 → yetkin
# 65+ → ahıl

# %% [markdown]
# #### 14. For Loop

# %%
# print multiple of 3 from 0 up to 30 (both included)
# 0-dan 30-a qədər 3-ə bölünən ədədləri çap edin (0 və 30 daxil olmaqla)

# %% [markdown]
# #### 15. Math Operations

# %%
# calculate square root of value until it is not a proper square of any number (print the result)
# alınan ədəd bir ədədin tam kvadratı olmayana qədər verilən ədədin kvadrat kökünü al (nəticəni çap et)
# məsələn ədəd = 16, kökü = 4, onun da kökü = 2
